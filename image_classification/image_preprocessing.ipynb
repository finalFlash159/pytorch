# %%
import torch
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
img = Image.open('../data/wonyoung.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1350>

# %%
# check image size
img.size
# Out:
# (1080, 1350)

# %% [markdown]
# ## Preprocess

# %%
preprocess_steps = transforms.Compose([
    transforms.Resize((300, 300)),
])
x = preprocess_steps(img)
x
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
preprocess_steps = transforms.Compose([
    transforms.Resize((300, 300)),
    transforms.RandomRotation(50),
])
x = preprocess_steps(img)
x
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
preprocess_steps = transforms.Compose([
    transforms.Resize((300, 300)),
    transforms.RandomRotation(50),
    transforms.CenterCrop(200),
])
x = preprocess_steps(img)
x
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
preprocess_steps = transforms.Compose([
    transforms.Resize((300, 300)),
    transforms.RandomRotation(50),
    transforms.CenterCrop(200),
    transforms.Grayscale(), 
])
x = preprocess_steps(img)
x
# Out:
# <PIL.Image.Image image mode=L size=200x200>

# %%
preprocess_steps = transforms.Compose([
    transforms.Resize((300, 300)),
    transforms.RandomRotation(50),
    transforms.CenterCrop(200),
    transforms.Grayscale(), 
    transforms.RandomVerticalFlip(),
])
x = preprocess_steps(img)
x
# Out:
# <PIL.Image.Image image mode=L size=200x200>

# %%
preprocess_steps = transforms.Compose([
    transforms.Resize((300, 300)),
    transforms.RandomRotation(50),
    transforms.CenterCrop(200),
    transforms.Grayscale(), 
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
])
x = preprocess_steps(img)
print(x.shape)
x
# Out:
# torch.Size([1, 200, 200])
# tensor([[[0.8863, 0.8863, 0.8863,  ..., 0.8863, 0.8863, 0.8863],
#          [0.8863, 0.8863, 0.8863,  ..., 0.8863, 0.8863, 0.8863],
#          [0.8863, 0.8863, 0.8863,  ..., 0.8824, 0.8863, 0.8863],
#          ...,
#          [0.0588, 0.0588, 0.0627,  ..., 0.8549, 0.8549, 0.8549],
#          [0.0588, 0.0588, 0.0627,  ..., 0.8549, 0.8510, 0.8549],
#          [0.0588, 0.0549, 0.0627,  ..., 0.8471, 0.8510, 0.8510]]])

# %% [markdown]
# ### Normalization

# %%
x.mean(), x.std()
# Out:
# (tensor(0.2830), tensor(0.2715))

# %%
preprocess_steps = transforms.Compose([
    transforms.Resize((300, 300)),
    transforms.RandomRotation(50),
    transforms.CenterCrop(200),
    transforms.Grayscale(), 
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])
x = preprocess_steps(img)
x.mean(), x.std()
# Out:
# (tensor(-0.4146), tensor(0.5626))
